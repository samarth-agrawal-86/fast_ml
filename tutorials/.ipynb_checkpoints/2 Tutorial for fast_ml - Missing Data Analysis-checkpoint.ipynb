# %% [markdown]
# # Tutorial for using the package `fast-ml`
#
# This package is as good as having a junior Data Scientist working for you. Most of the commonly used EDA steps, Missing Data Imputation techniques, Feature Engineering steps are covered in a ready to use format

# %% [markdown]
# ## Part 2. Missing Data Imputation for Numerical Variables & Categorical Variables
#
#
#
# #### 1. Import eda module from the package
# `from fast_ml.missing_data_analysis import MissingDataAnalysis`
#
#
# #### 2. Define the Missing Data Analysis (mda) object.
# `mda_obj = MissingDataAnalysis(df, target=, model = )`
#
# #### 3. Select a variable and run the command for various exploratory analysis
# * For Categorical variables use `explore_categorical_imputation`
# * For Numerical variables use `explore_numerical_imputation`
#
# `mda_obj.explore_categorical_imputation('BsmtQual')`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from fast_ml.missing_data_analysis import MissingDataAnalysis

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/house_prices.csv')
df.shape
# Out:
# (1460, 81)

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Start Missing Data Analysis

# %%
# Define Missing Data Analysis Object
mda_obj = MissingDataAnalysis(df, target='SalePrice', model = 'regression')

# %%
mda_obj.calculate_missing_values()
# Out:
#        variables    na_perc    dtype
# 0         PoolQC  99.520548   object
# 1    MiscFeature  96.301370   object
# 2          Alley  93.767123   object
# 3          Fence  80.753425   object
# 4    FireplaceQu  47.260274   object
# 5    LotFrontage  17.739726  float64
# 6     GarageType   5.547945   object
# 7    GarageYrBlt   5.547945  float64
# 8   GarageFinish   5.547945   object
# 9     GarageQual   5.547945   object
# 10    GarageCond   5.547945   object
# 11  BsmtExposure   2.602740   object
# 12  BsmtFinType2   2.602740   object
# 13  BsmtFinType1   2.534247   object
# 14      BsmtCond   2.534247   object
# 15      BsmtQual   2.534247   object
# 16    MasVnrArea   0.547945  float64
# 17    MasVnrType   0.547945   object
# 18    Electrical   0.068493   object

# %% [markdown]
# ## Numerical Variables

# %% [markdown]
# ### 1. LotFrontage

# %%
# Use the following method for a numerical variable 
eda_obj.eda_numerical_variable('MSSubClass')

# %% [markdown]
# ### 2.  GarageYrBlt

# %%
# Use the following method for a numerical variable 
eda_obj.eda_numerical_variable('LotFrontage')

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### 1. BsmtQual

# %%
# Use the following method for a categorical variable 
mda_obj.explore_categorical_imputation('BsmtQual')
# Out:
# **<u>Missing Values :</u>**
#   Number : 37
#   Percentage : 2.5342465753424657 %
# **<u>We have following options for Imputing the Missing Value for Categorical Variable, BsmtQual :</u>**
#   1. Imputing missing values by Frequent Category
#   2. Imputing missing values by Missing Label
#   3. Imputing missing values by Randomly selected value
#
# Let's visualize the impact of each imputation and compare it with original distribution
# **<u>1. Original Distribution of all Categories :</u>**
# **<u>2. All Categories after Frequent Category Imputation :</u>**
# Look at the Distibution of Frequent Category and Missing Data. Are there some major differences
#
#
# Most Frequent Category:  TA
# 3. All Categories after Missing Label Imputation
# 4. All Categories after Randomly Selected Value Imputation

# %% [markdown]
# ### 2. FireplaceQu

# %%
# Use the following method for a categorical variable 
mda_obj.explore_categorical_imputation('FireplaceQu')
# Out:
# **<u>Missing Values :</u>**
#   Number : 690
#   Percentage : 47.26027397260274 %
# **<u>We have following options for Imputing the Missing Value for Categorical Variable, FireplaceQu :</u>**
#   1. Imputing missing values by Frequent Category
#   2. Imputing missing values by Missing Label
#   3. Imputing missing values by Randomly selected value
#
# Let's visualize the impact of each imputation and compare it with original distribution
# **<u>1. Original Distribution of all Categories :</u>**
# **<u>2. All Categories after Frequent Category Imputation :</u>**
# Look at the Distibution of Frequent Category and Missing Data. Are there some major differences
#
#
# Most Frequent Category:  Gd
# 3. All Categories after Missing Label Imputation
# 4. All Categories after Randomly Selected Value Imputation
